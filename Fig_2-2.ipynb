# %% [markdown]
# # Código de la figura 2.2: Evolucion de v en el caso I_0 = 0

# %% [markdown]
# # 0. Importar bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Creación de funciones

# %%
def dv_dt(v, t):
    return -v

# %% [markdown]
# # 2. Variables de entorno
#
# t = Crear un espacio de tiempo de 0 a 10 con 100 puntos \
# v(0) = 1 es el valor inicial del potencial \
# v calcula los valores de v(t) utilizando la solución de la ecuación diferencial

# %%
t = np.linspace(0, 10, 100) 
v0 = 1.0
v = v0 * np.exp(-t)

# %% [markdown]
# # 3. Dibujo de la gráfica

# %%
plt.plot(t, v, label='dv/dt = -v')
plt.xlabel('Tiempo')
plt.ylabel('v(t)')
plt.legend()
plt.show()
